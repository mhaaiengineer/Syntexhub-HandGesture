# %% [markdown]
# # ✋ AI Hand Gesture Recognition (Webcam Demo)
#
# This notebook runs the same webcam demo as `run_webcam.py`, but inside Jupyter.
#
# **Tip:** For safety, actions are **DISARMED by default**. Press **A** in the webcam window to arm.

# %%
# !pip -q install -r ../requirements.txt

# %%
from src.app import HandGestureApp
from src.config import RuntimeConfig

app = HandGestureApp(RuntimeConfig())
app.run()
